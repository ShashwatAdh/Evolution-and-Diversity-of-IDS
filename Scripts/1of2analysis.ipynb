# %%
import pandas as pd
import numpy as np

# %%
snort_ds3_2017=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/snort_ds3/snort_ds3_2017.csv')
snort_ds3_2018=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/snort_ds3/snort_ds3_2018.csv')
snort_ds3_2019=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/snort_ds3/snort_ds3_2019.csv')
snort_ds3_2020=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/snort_ds3/snort_ds3_2020.csv')
suricata_ds3_2017=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/suricata_ds3/suricata_ds3_2017.csv')
suricata_ds3_2018=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/suricata_ds3/suricata_ds3_2018.csv')
suricata_ds3_2019=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/suricata_ds3/suricata_ds3_2019.csv')
suricata_ds3_2020=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/suricata_ds3/suricata_ds3_2020.csv')

# %%
snort_ds2_2017=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/snort_ds2/snort_ds2_2017.csv')
snort_ds2_2018=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/snort_ds2/snort_ds2_2018.csv')
snort_ds2_2019=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/snort_ds2/snort_ds2_2019.csv')
snort_ds2_2020=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/snort_ds2/snort_ds2_2020.csv')
suricata_ds2_2017=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/suricata_ds2/suricata_ds2_2017.csv')
suricata_ds2_2018=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/suricata_ds2/suricata_ds2_2018.csv')
suricata_ds2_2019=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/suricata_ds2/suricata_ds2_2019.csv')
suricata_ds2_2020=pd.read_csv('/home/exp-1/Desktop/data/Alerts/Alerts_csv/suricata_ds2/suricata_ds2_2020.csv')

# %%
#Read Labels:
ds2_label=pd.read_csv('/home/exp-1/Desktop/data/timestamp_plot/ds2_label.csv')
ds3_label=pd.read_csv('/home/exp-1/Desktop/data/timestamp_plot/ds3_label.csv')

# %%
snort_ds3_2017['id']=snort_ds3_2017['event.source-ip']+'-'+snort_ds3_2017['event.destination-ip']+'-'+snort_ds3_2017['event.sport-itype'].astype(int).astype(str)+'-'+snort_ds3_2017['event.dport-icode'].astype(int).astype(str)+'-'+snort_ds3_2017['date'].astype(str)
snort_ds3_2018['id']=snort_ds3_2018['event.source-ip']+'-'+snort_ds3_2018['event.destination-ip']+'-'+snort_ds3_2018['event.sport-itype'].astype(int).astype(str)+'-'+snort_ds3_2018['event.dport-icode'].astype(int).astype(str)+'-'+snort_ds3_2018['date'].astype(str)
snort_ds3_2019['id']=snort_ds3_2019['event.source-ip']+'-'+snort_ds3_2019['event.destination-ip']+'-'+snort_ds3_2019['event.sport-itype'].astype(int).astype(str)+'-'+snort_ds3_2019['event.dport-icode'].astype(int).astype(str)+'-'+snort_ds3_2019['date'].astype(str)
snort_ds3_2020['id']=snort_ds3_2020['event.source-ip']+'-'+snort_ds3_2020['event.destination-ip']+'-'+snort_ds3_2020['event.sport-itype'].astype(int).astype(str)+'-'+snort_ds3_2020['event.dport-icode'].astype(int).astype(str)+'-'+snort_ds3_2020['date'].astype(str)
suricata_ds3_2017['id']=suricata_ds3_2017['src_ip']+'-'+suricata_ds3_2017['dest_ip']+'-'+suricata_ds3_2017['src_port'].astype(int).astype(str)+'-'+suricata_ds3_2017['dest_port'].astype(int).astype(str)+'-'+suricata_ds3_2017['date'].astype(str)
suricata_ds3_2018['id']=suricata_ds3_2018['src_ip']+'-'+suricata_ds3_2018['dest_ip']+'-'+suricata_ds3_2018['src_port'].astype(int).astype(str)+'-'+suricata_ds3_2018['dest_port'].astype(int).astype(str)+'-'+suricata_ds3_2018['date'].astype(str)
suricata_ds3_2019['id']=suricata_ds3_2019['src_ip']+'-'+suricata_ds3_2019['dest_ip']+'-'+suricata_ds3_2019['src_port'].astype(int).astype(str)+'-'+suricata_ds3_2019['dest_port'].astype(int).astype(str)+'-'+suricata_ds3_2019['date'].astype(str)
suricata_ds3_2020['id']=suricata_ds3_2020['src_ip']+'-'+suricata_ds3_2020['dest_ip']+'-'+suricata_ds3_2020['src_port'].astype(int).astype(str)+'-'+suricata_ds3_2020['dest_port'].astype(int).astype(str)+'-'+suricata_ds3_2020['date'].astype(str)

# %%
snort_ds2_2017['id']=snort_ds2_2017['event.source-ip']+'-'+snort_ds2_2017['event.destination-ip']+'-'+snort_ds2_2017['event.sport-itype'].astype(int).astype(str)+'-'+snort_ds2_2017['event.dport-icode'].astype(int).astype(str)+'-'+snort_ds2_2017['date'].astype(str)
snort_ds2_2018['id']=snort_ds2_2018['event.source-ip']+'-'+snort_ds2_2018['event.destination-ip']+'-'+snort_ds2_2018['event.sport-itype'].astype(int).astype(str)+'-'+snort_ds2_2018['event.dport-icode'].astype(int).astype(str)+'-'+snort_ds2_2018['date'].astype(str)
snort_ds2_2019['id']=snort_ds2_2019['event.source-ip']+'-'+snort_ds2_2019['event.destination-ip']+'-'+snort_ds2_2019['event.sport-itype'].astype(int).astype(str)+'-'+snort_ds2_2019['event.dport-icode'].astype(int).astype(str)+'-'+snort_ds2_2019['date'].astype(str)
snort_ds2_2020['id']=snort_ds2_2020['event.source-ip']+'-'+snort_ds2_2020['event.destination-ip']+'-'+snort_ds2_2020['event.sport-itype'].astype(int).astype(str)+'-'+snort_ds2_2020['event.dport-icode'].astype(int).astype(str)+'-'+snort_ds2_2020['date'].astype(str)
suricata_ds2_2017['id']=suricata_ds2_2017['src_ip']+'-'+suricata_ds2_2017['dest_ip']+'-'+suricata_ds2_2017['src_port'].astype(int).astype(str)+'-'+suricata_ds2_2017['dest_port'].astype(int).astype(str)+'-'+suricata_ds2_2017['date'].astype(str)
suricata_ds2_2018['id']=suricata_ds2_2018['src_ip']+'-'+suricata_ds2_2018['dest_ip']+'-'+suricata_ds2_2018['src_port'].astype(int).astype(str)+'-'+suricata_ds2_2018['dest_port'].astype(int).astype(str)+'-'+suricata_ds2_2018['date'].astype(str)
suricata_ds2_2019['id']=suricata_ds2_2019['src_ip']+'-'+suricata_ds2_2019['dest_ip']+'-'+suricata_ds2_2019['src_port'].astype(int).astype(str)+'-'+suricata_ds2_2019['dest_port'].astype(int).astype(str)+'-'+suricata_ds2_2019['date'].astype(str)
suricata_ds2_2020['id']=suricata_ds2_2020['src_ip']+'-'+suricata_ds2_2020['dest_ip']+'-'+suricata_ds2_2020['src_port'].astype(int).astype(str)+'-'+suricata_ds2_2020['dest_port'].astype(int).astype(str)+'-'+suricata_ds2_2020['date'].astype(str)

# %%
snort_ds2_2017
# Out:
#       event.source-ip event.destination-ip  event.sport-itype  \
# 0        192.168.10.3        192.168.10.19               88.0
# 1        192.168.10.3        192.168.10.19               88.0
# 2        192.168.10.3        192.168.10.19               88.0
# 3        192.168.10.3        192.168.10.19               88.0
# 4        192.168.10.3        192.168.10.19               88.0
# ...               ...                  ...                ...
# 29904   68.67.178.196        192.168.10.14               80.0
# 29905   192.168.10.14        74.119.118.82            51633.0
# 29906   192.168.10.15        38.72.130.155            61245.0
# 29907   74.119.118.74        192.168.10.51               80.0
# 29908   68.67.178.110         192.168.10.8               80.0
#
#        event.dport-icode  event.protocol  event.event-second  \
# 0                41567.0             6.0        1.499342e+09
# 1                41567.0             6.0        1.499342e+09
# ...

# %%
snort_ds2_2017.rename(columns={'event.source-ip':'src_ip', 'event.destination-ip':'dest_ip', 'event.sport-itype':'src_port', 'event.dport-icode':'dest_port'}, inplace=True)
snort_ds2_2018.rename(columns={'event.source-ip':'src_ip', 'event.destination-ip':'dest_ip', 'event.sport-itype':'src_port', 'event.dport-icode':'dest_port'}, inplace=True)
snort_ds2_2019.rename(columns={'event.source-ip':'src_ip', 'event.destination-ip':'dest_ip', 'event.sport-itype':'src_port', 'event.dport-icode':'dest_port'}, inplace=True)
snort_ds2_2020.rename(columns={'event.source-ip':'src_ip', 'event.destination-ip':'dest_ip', 'event.sport-itype':'src_port', 'event.dport-icode':'dest_port'}, inplace=True)

# %%
snort_ds3_2017.rename(columns={'event.source-ip':'src_ip', 'event.destination-ip':'dest_ip', 'event.sport-itype':'src_port', 'event.dport-icode':'dest_port'}, inplace=True)
snort_ds3_2018.rename(columns={'event.source-ip':'src_ip', 'event.destination-ip':'dest_ip', 'event.sport-itype':'src_port', 'event.dport-icode':'dest_port'}, inplace=True)
snort_ds3_2019.rename(columns={'event.source-ip':'src_ip', 'event.destination-ip':'dest_ip', 'event.sport-itype':'src_port', 'event.dport-icode':'dest_port'}, inplace=True)
snort_ds3_2020.rename(columns={'event.source-ip':'src_ip', 'event.destination-ip':'dest_ip', 'event.sport-itype':'src_port', 'event.dport-icode':'dest_port'}, inplace=True)

# %%
ds2_2017=pd.concat([snort_ds2_2017,suricata_ds2_2017]).drop_duplicates('id').reset_index(drop=True)
ds2_2018=pd.concat([snort_ds2_2018,suricata_ds2_2018]).drop_duplicates('id').reset_index(drop=True)
ds2_2019=pd.concat([snort_ds2_2019,suricata_ds2_2019]).drop_duplicates('id').reset_index(drop=True)
ds2_2020=pd.concat([snort_ds2_2020,suricata_ds2_2020]).drop_duplicates('id').reset_index(drop=True)

# %%
ds3_2017=pd.concat([snort_ds3_2017,suricata_ds3_2017]).drop_duplicates('id').reset_index(drop=True)
ds3_2018=pd.concat([snort_ds3_2018,suricata_ds3_2018]).drop_duplicates('id').reset_index(drop=True)
ds3_2019=pd.concat([snort_ds3_2019,suricata_ds3_2019]).drop_duplicates('id').reset_index(drop=True)
ds3_2020=pd.concat([snort_ds3_2020,suricata_ds3_2020]).drop_duplicates('id').reset_index(drop=True)

# %%
ds2_2017
# Out:
#                src_ip        dest_ip  src_port  dest_port  event.protocol  \
# 0        192.168.10.3  192.168.10.19      88.0    41567.0             6.0
# 1        192.168.10.3  192.168.10.19      88.0    41567.0             6.0
# 2        192.168.10.3  192.168.10.19      88.0    41569.0             6.0
# 3        192.168.10.3  192.168.10.19      88.0    41569.0             6.0
# 4        192.168.10.3  192.168.10.19      88.0    41574.0             6.0
# ...               ...            ...       ...        ...             ...
# 54019    192.168.10.8  192.225.158.2   61101.0     3478.0             NaN
# 54020   192.225.158.2   192.168.10.8    3478.0    61101.0             NaN
# 54021   212.239.56.65  192.168.10.25     443.0    53873.0             NaN
# 54022  158.69.247.184  192.168.10.19     123.0      123.0             NaN
# 54023   212.239.56.65  192.168.10.25     443.0    53996.0             NaN
#
#        event.event-second  event.event-microsecond  \
# ...

# %%
ds2_2017['positives'].value_counts()
# Out:
# False    24022
# True      1487
# Name: positives, dtype: int64

# %%
ds2_2018['positives'].value_counts()
# Out:
# False    24188
# True      1417
# Name: positives, dtype: int64

# %%
ds2_2019['positives'].value_counts()
# Out:
# False    24209
# True      1415
# Name: positives, dtype: int64

# %%
ds2_2020['positives'].value_counts()
# Out:
# False    29857
# True      1647
# Name: positives, dtype: int64

# %%
ds3_2017['positives'].value_counts()
# Out:
# False    1165467
# True        2638
# Name: positives, dtype: int64

# %%
ds3_2018['positives'].value_counts()
# Out:
# False    1166095
# True        2666
# Name: positives, dtype: int64

# %%
ds3_2019['positives'].value_counts()
# Out:
# False    1166493
# True        2511
# Name: positives, dtype: int64

# %%
ds3_2020['positives'].value_counts()
# Out:
# False    1166155
# True        2554
# Name: positives, dtype: int64

# %%
snort_ds2_2020['date'].isin(suricata_ds2_2020['date']).value_counts()
# Out:
# False    35269
# True      1978
# Name: date, dtype: int64

# %%
snort_ds2_2020['src_ip'].isin(suricata_ds2_2020['src_ip']).value_counts()
# Out:
# True     28312
# False     8935
# Name: src_ip, dtype: int64

# %%
snort_ds2_2020['dest_ip'].isin(suricata_ds2_2020['dest_ip']).value_counts()
# Out:
# False    23385
# True     13862
# Name: dest_ip, dtype: int64

# %%
snort_ds2_2020['src_port'].isin(suricata_ds2_2020['src_port']).value_counts()
# Out:
# False    28927
# True      8320
# Name: src_port, dtype: int64

# %%
snort_ds2_2020['dest_port'].isin(suricata_ds2_2020['dest_port']).value_counts()
# Out:
# False    26302
# True     10945
# Name: dest_port, dtype: int64

# %%
snort_ds2_2020
# Out:
#               src_ip        dest_ip  src_port  dest_port  event.protocol  \
# 0       192.168.10.3  192.168.10.19      88.0    41567.0             6.0
# 1       192.168.10.3  192.168.10.19      88.0    41567.0             6.0
# 2       192.168.10.3  192.168.10.19      88.0    41569.0             6.0
# 3       192.168.10.3  192.168.10.19      88.0    41569.0             6.0
# 4       192.168.10.3  192.168.10.19      88.0    41574.0             6.0
# ...              ...            ...       ...        ...             ...
# 37242  68.67.178.196  192.168.10.14      80.0    51631.0             6.0
# 37243  192.168.10.14  74.119.118.82   51633.0       80.0             6.0
# 37244  192.168.10.15  38.72.130.155   61245.0       80.0             6.0
# 37245  74.119.118.74  192.168.10.51      80.0    44693.0             6.0
# 37246  68.67.178.110   192.168.10.8      80.0     1944.0             6.0
#
#        event.event-second  event.event-microsecond  \
# ...
